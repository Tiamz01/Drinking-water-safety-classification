# %%
# !pip freeze | grep scikit-learn
# Out:
# scikit-learn==1.5.1

# %%
# !python -V
# Out:
# Python 3.10.14

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
data =  pd.read_csv('01-data_collection_and_model/data/waterQuality.csv')

data
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 1          2.32   21.16     0.01    3.31    0.002        5.28      0.68
# 2          1.01   14.02     0.04    0.58    0.008        4.24      0.53
# 3          1.36   11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92   24.33     0.03    0.20    0.006        2.67      0.69
# ...         ...     ...      ...     ...      ...         ...       ...
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01      10     0.01    2.00    0.000        2.00      0.00
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %%
data = data.copy()

# %%
data.shape
# Out:
# (7999, 21)

# %% [markdown]
# ## EDA

# %%
data.describe()
# Out:
#          aluminium      arsenic       barium      cadmium   chloramine  \
# count  7999.000000  7999.000000  7999.000000  7999.000000  7999.000000
# mean      0.666158     0.161445     1.567715     0.042806     2.176831
# std       1.265145     0.252590     1.216091     0.036049     2.567027
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.040000     0.030000     0.560000     0.008000     0.100000
# 50%       0.070000     0.050000     1.190000     0.040000     0.530000
# 75%       0.280000     0.100000     2.480000     0.070000     4.240000
# max       5.050000     1.050000     4.940000     0.130000     8.680000
#
#           chromium       copper     flouride     bacteria      viruses  \
# count  7999.000000  7999.000000  7999.000000  7999.000000  7999.000000
# mean      0.247226     0.805857     0.771565     0.319665     0.328583
# std       0.270640     0.653539     0.435373     0.329485     0.378096
# ...

# %%
print(data.dtypes)
# Out:
# aluminium      float64
# ammonia         object
# arsenic        float64
# barium         float64
# cadmium        float64
# chloramine     float64
# chromium       float64
# copper         float64
# flouride       float64
# bacteria       float64
# viruses        float64
# lead           float64
# nitrates       float64
# nitrites       float64
# mercury        float64
# perchlorate    float64
# radium         float64
# selenium       float64
# silver         float64
# uranium        float64
# is_safe         object
# dtype: object

# %%
data.replace('#NUM!', np.nan, inplace=True)

# %%
data.isnull().sum()
# Out:
# aluminium      0
# ammonia        3
# arsenic        0
# barium         0
# cadmium        0
# chloramine     0
# chromium       0
# copper         0
# flouride       0
# bacteria       0
# viruses        0
# lead           0
# nitrates       0
# nitrites       0
# mercury        0
# perchlorate    0
# radium         0
# selenium       0
# silver         0
# uranium        0
# is_safe        3
# dtype: int64

# %%
data.dropna()
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 1          2.32   21.16     0.01    3.31    0.002        5.28      0.68
# 2          1.01   14.02     0.04    0.58    0.008        4.24      0.53
# 3          1.36   11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92   24.33     0.03    0.20    0.006        2.67      0.69
# ...         ...     ...      ...     ...      ...         ...       ...
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01      10     0.01    2.00    0.000        2.00      0.00
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %%
# Convert all columns to numeric, forcing non-numeric values to NaN
data = data.apply(pd.to_numeric, errors='coerce')

cleaned_data = data.dropna()

# %%
df = cleaned_data.copy()

# %%
df.hist(figsize=(20, 15))
plt.show()

# %%
for column in data.columns:
    plt.figure(figsize=(10, 5))
    sns.boxplot(x=data[column])
    plt.title(f'Box plot of {column}')
    plt.show()

# %%
corr_matrix = data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
sns.countplot(x='is_safe', data=df)
plt.title('Distribution of Target Variable (is_safe)')
plt.show()

# %% [markdown]
# ### Feature Engineering

# %%
from sklearn.preprocessing import StandardScaler

# Features and target variable
X = df.drop(columns=['is_safe'])
y = df['is_safe']

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
import os
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '/home/t.sukanmi/mlops-429011-853523c01da8.json'

print(os.environ.get('GOOGLE_APPLICATION_CREDENTIALS'))

# Ensure the environment variable is set
credentials_path = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')
if not credentials_path:
    raise ValueError("GOOGLE_APPLICATION_CREDENTIALS environment variable not set.")

# Set the environment variable for Google Cloud SDK
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credentials_path
# Out:
# /home/t.sukanmi/mlops-429011-853523c01da8.json

# %%
from google.cloud import storage
from google.oauth2 import service_account

credentials_path = "/home/t.sukanmi/mlops-429011-cabe2d4c4fed.json"
credentials = service_account.Credentials.from_service_account_file(credentials_path)
client = storage.Client(credentials=credentials, project="mlops-429011")

# List buckets to verify
for bucket in client.list_buckets():
    print(bucket.name)
# Out:
# water_quality_model

# %%
import mlflow.sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

# Example setup, replace with your actual code
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

log_reg = LogisticRegression()
param_grid = {'C': [0.1, 1, 10], 'penalty': ['l1', 'l2'], 'solver': ['liblinear']}
grid_search = GridSearchCV(log_reg, param_grid, cv=5)
grid_search.fit(X_train, y_train)

mlflow.sklearn.log_model(grid_search.best_estimator_, 'model/log_reg_WQC_model')
# Out:
# /home/t.sukanmi/anaconda3/envs/clsproject/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /home/t.sukanmi/anaconda3/envs/clsproject/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# ---------------------------------------------------------------------------
# InvalidOperation                          Traceback (most recent call last)
# Cell In[75], line 13
#      10 grid_search = GridSearchCV(log_reg, param_grid, cv=5)
# ...

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, roc_curve, auc, classification_report, confusion_matrix, precision_score, recall_score, f1_score

import mlflow
import mlflow.sklearn
from google.cloud import storage as gcs_storage
from google.auth.exceptions import DefaultCredentialsError

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# %%
MLFLOW_TRACKING_URI = 'http://35.192.179.167:5000/'
mlflow.set_tracking_uri(uri=MLFLOW_TRACKING_URI)
mlflow.set_experiment('water quality')
# Out:
# <Experiment: artifact_location='gs://water_quality_model/1', creation_time=1721503205449, experiment_id='1', last_update_time=1721503205449, lifecycle_stage='active', name='water quality', tags={}>

# %%
with mlflow.start_run():
    mlflow.set_tag('model', 'log-reg')

    # Train the model
    log_reg = LogisticRegression()
    # Create a pipeline with feature scaling and logistic regression
    pipeline = Pipeline([
        ('scaler', StandardScaler()),
        ('log_reg', log_reg)
    ])

    # Define the parameter grid
    param_grid = {
        'log_reg__C': [0.01, 0.1, 1, 10, 100],
        'log_reg__solver': ['liblinear', 'saga'],
        'log_reg__penalty': ['l1', 'l2']
    }

    # Initialize GridSearchCV
    grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='accuracy')

    # Fit the model
    grid_search.fit(X_train, y_train)

    # Print the best parameters and best score
    print(f"Best parameters: {grid_search.best_params_}")
    print(f"Best accuracy: {grid_search.best_score_}")

    # Log the best model
    mlflow.sklearn.log_model(grid_search.best_estimator_, 'model/log_reg_WQC_model')

    # Evaluate the model on the test set
    y_pred = grid_search.best_estimator_.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)

    # Log metrics
    mlflow.log_metric('accuracy', accuracy)
    mlflow.log_metric('precision', precision)
    mlflow.log_metric('recall', recall)
    mlflow.log_metric('f1', f1)

    # Print metrics
    print(f'Accuracy: {accuracy:.2f}')
    print(f'Precision: {precision:.2f}')
    print(f'Recall: {recall:.2f}')
    print(f'F1 Score: {f1:.2f}')
    print('Confusion Matrix:')
    print(conf_matrix)
    print('Classification Report:')
    print(class_report)
# Out:
# Best parameters: {'log_reg__C': 1, 'log_reg__penalty': 'l1', 'log_reg__solver': 'liblinear'}
# Best accuracy: 0.9112026043661432
# /home/t.sukanmi/anaconda3/envs/clsproject/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /home/t.sukanmi/anaconda3/envs/clsproject/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# ---------------------------------------------------------------------------
# ...

# %%
with mlflow.start_run():

    param_grid = {
        'n_estimators': [50, 100, 150],
        'learning_rate': [0.05, 0.1, 0.2],
        'max_depth': [3, 4, 5]
    }

    # Perform grid search with cross-validation
    gb_clf = GradientBoostingClassifier(random_state=42)
    grid_search = GridSearchCV(estimator=gb_clf, param_grid=param_grid, cv=5, scoring='accuracy', verbose=1, n_jobs=-1)

    # Fit the grid search object
    grid_search.fit(X_train, y_train)

    # Evaluate the best model
    best_gb_clf = grid_search.best_estimator_
    y_pred = best_gb_clf.predict(X_test)

    mlflow.log_params(param_grid)
    mlflow.log_param('best params', grid_search.best_params_)
    
    # Log the model
    mlflow.sklearn.log_model(best_gb_clf, 'model/gb_model')
    


    print('Best Parameters found:')
    print(grid_search.best_params_)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    conf_matrix = confusion_matrix(y_test, y_pred)
    class_report = classification_report(y_test, y_pred)

    mlflow.log_metric('accuracy', accuracy)
    mlflow.log_metric('precision', precision)
    mlflow.log_metric('recall', recall)
    mlflow.log_metric('f1', f1)

    print(f'Accuracy: {accuracy:.2f}')
    print(f'Precision_score: {precision:.2f}')
    print(f'recall_score: {recall:.2f}')
    print(f'f1_score: {f1:.2f}')
    print('Confusion Matrix:')
    print(conf_matrix)
    print('Classification Report:')
    print(class_report)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# /home/t.sukanmi/anaconda3/envs/clsproject/lib/python3.10/site-packages/_distutils_hack/__init__.py:11: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /home/t.sukanmi/anaconda3/envs/clsproject/lib/python3.10/site-packages/_distutils_hack/__init__.py:26: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Best Parameters found:
# {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 150}
# Accuracy: 0.97
# Precision_score: 0.94
# recall_score: 0.79
# f1_score: 0.86
# Confusion Matrix:
# [[2076   15]
# ...

# %%
y_pred_prob = best_gb_clf.predict_proba(X_test)
y_pred_prob = y_pred_prob[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

# %%
# Plot AUC
plt.figure(figsize=(14, 6))

# ROC Curve
plt.subplot(1, 2, 1)
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')

# Confusion Matrix
plt.subplot(1, 2, 2)
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False, annot_kws={"size": 16})
plt.xlabel('Predicted label')
plt.ylabel('True label')
plt.title('Confusion Matrix')

# Display precision and recall
plt.figtext(0.5, 0.01, f'Precision: {precision:.2f} | Recall: {recall:.2f}', ha='center', fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Model Registry

# %% [markdown]
# mlflow server -h 0.0.0.0 -p 5000 --backend-store-uri postgresql://waterDB:padlock02@10.110.160.4:5432/mlflow --default-artifact-root gs://water_quality_model

# %%
from mlflow.tracking import MlflowClient

# Interacting with MLflow Tracking Server to extract run ids with higher accuracy
client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
from mlflow.entities import ViewType
runs = client.search_runs(
    experiment_ids='1',
    filter_string="metrics.f1 > 0.7",
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=5,
    order_by=["metrics.f1 DESC"]
)

for run in runs:
    print(f"run id: {run.info.run_id}, f1_score: {run.data.metrics['f1']:.4f}")
# Out:
# run id: b08127df57c042aa8e5ac689c435bc03, f1_score: 0.8607
# run id: 3bbe671a3b694fbca26671b3f6a62b85, f1_score: 0.8607
# run id: 92ed3598bc6f4de28f3ed7f8d24eb1b2, f1_score: 0.8607
# run id: a6b2b88ac6e84fc99d7b82b03232c847, f1_score: 0.8607
# run id: b148d239d6b84b08961892fe7b8dfc95, f1_score: 0.8607

# %%
# Interacting with the Model Registry
mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

run_id = "b148d239d6b84b08961892fe7b8dfc95"
model_uri = f"runs:/{run_id}/model"
mlflow.register_model(model_uri=model_uri, name="water_quality")
# Out:
# Registered model 'water_quality' already exists. Creating a new version of this model...
# 2024/07/22 09:46:24 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: water_quality, version 7
# Created version '7' of model 'water_quality'.
# <ModelVersion: aliases=[], creation_timestamp=1721641584868, current_stage='None', description='', last_updated_timestamp=1721641584868, name='water_quality', run_id='b148d239d6b84b08961892fe7b8dfc95', run_link='', source='gs://water_quality_model/1/b148d239d6b84b08961892fe7b8dfc95/artifacts/model', status='READY', status_message='', tags={}, user_id='', version='7'>

# %%
model_name = "water_quality"
latest_versions = client.get_latest_versions(name=model_name)

for version in latest_versions:
    print(f"version: {version.version}, stage: {version.current_stage}")
# Out:
# version: 1, stage: Production
# version: 7, stage: None
# version: 3, stage: Staging
# /tmp/ipykernel_21169/1136583808.py:2: FutureWarning: ``mlflow.tracking.client.MlflowClient.get_latest_versions`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/latest/model-registry.html#migrating-from-stages
#   latest_versions = client.get_latest_versions(name=model_name)

# %%
model_version = 3
new_stage = "Staging"
client.transition_model_version_stage(
    name=model_name,
    version=model_version,
    stage=new_stage,
    archive_existing_versions=True
)
# Out:
# /tmp/ipykernel_21169/2050150494.py:3: FutureWarning: ``mlflow.tracking.client.MlflowClient.transition_model_version_stage`` is deprecated since 2.9.0. Model registry stages will be removed in a future major release. To learn more about the deprecation of model registry stages, see our migration guide here: https://mlflow.org/docs/latest/model-registry.html#migrating-from-stages
#   client.transition_model_version_stage(
# <ModelVersion: aliases=[], creation_timestamp=1721522703728, current_stage='Staging', description='', last_updated_timestamp=1721641584968, name='water_quality', run_id='b148d239d6b84b08961892fe7b8dfc95', run_link='', source='gs://water_quality_model/1/b148d239d6b84b08961892fe7b8dfc95/artifacts/model', status='READY', status_message='', tags={}, user_id='', version='3'>

# %% [markdown]
# TEST THE MODEL IN PRODUCTION

# %%
train,test = train_test_split(df,random_state=42)
train_x = train.drop(["is_safe"],axis=1)
test_x = test.drop(["is_safe"],axis=1)

train_y = train[["is_safe"]]
test_y = test[["is_safe"]]

X_test=test_x
y_test=test_y

# %%
import mlflow.sklearn

# Define the model URI (ensure this is correct and points to the MLflow model directory)
model_uri = "gs://water_quality_model/1/b148d239d6b84b08961892fe7b8dfc95/artifacts/model/gb_model"

# Load the model from the artifact URI
model = mlflow.sklearn.load_model(model_uri)

# Use the model for predictions
predictions = model.predict(X_test)
predictions
# Out:
# /home/t.sukanmi/anaconda3/envs/clsproject/lib/python3.10/site-packages/sklearn/base.py:486: UserWarning: X has feature names, but GradientBoostingClassifier was fitted without feature names
#   warnings.warn(
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# Following setps involved to setup MLFlow on GCP:
# Create a PostgreSQL DB for storing model metadata.
# Create a Google Cloud Storage Bucket for storing artifacts.
# Create a Compute Engine instance to install MLFlow and run the MLFlow server
# SSH into Compute machine using the UI and run following commands:
# sudo apt update
# pip3 install mlflow psycopg2-binary
# mlflow server -h 0.0.0.0 -p 5000 --backend-store-uri postgresql://DB_USER:DB_PASSWORD@DB_ENDPOINT:5432/DB_NAME --default-artifact-root gs://GS_BUCKET_NAME '''
